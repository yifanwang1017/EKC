# %%
import pandas as pd

# %%
data = pd.read_excel('inference data.xlsx')
data.head()
# Out:
#           p  crash  volume  temperature  season weather    daytime  \
# 0  0.000403      0       0            0  autumn  cloudy  afternoon
# 1  0.000010      1       0            0  autumn  cloudy  afternoon
# 2  0.000222      0       1            0  autumn  cloudy  afternoon
# 3  0.000014      1       1            0  autumn  cloudy  afternoon
# 4  0.000197      0       2            0  autumn  cloudy  afternoon
#
#    time of week
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
data.head()
# Out:
#           p  crash  volume  temperature  season weather    daytime  \
# 0  0.000403      0       0            0  autumn  cloudy  afternoon
# 1  0.000010      1       0            0  autumn  cloudy  afternoon
# 2  0.000222      0       1            0  autumn  cloudy  afternoon
# 3  0.000014      1       1            0  autumn  cloudy  afternoon
# 4  0.000197      0       2            0  autumn  cloudy  afternoon
#
#    time of week
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
data_crash = data[data['crash']==1]
print(len(data_crash))
# Out:
# 3240

# %%
data_crash = data_crash.sort_values(by='p',ascending=0)
data_crash.head(10)
# Out:
#              p  crash  volume  temperature  season weather    daytime  \
# 1137  0.000481      1       1            0  winter  cloudy    morning
# 1857  0.000471      1       1            0  winter  cloudy       noon
# 1495  0.000438      1       0            0  winter  cloudy      night
# 415   0.000422      1       0            0  winter  cloudy       dawn
# 57    0.000407      1       1            0  winter  cloudy  afternoon
# 777   0.000359      1       1            0  winter  cloudy    evening
# 51    0.000330      1       1            2  summer  cloudy  afternoon
# 775   0.000321      1       0            0  winter  cloudy    evening
# 1851  0.000275      1       1            2  summer  cloudy       noon
# 55    0.000229      1       0            0  winter  cloudy  afternoon
#
#       time of week
# 1137             0
# 1857             0
# 1495             0
# 415              0
# 57               0
# 777              0
# 51               0
# 775              0
# ...
