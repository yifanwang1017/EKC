# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('模型数据.xlsx')
data.head(2)
# Out:
#    crash  time of week weather  volume  temperature    daytime  season
# 0      1             1  cloudy       0            0  afternoon  winter
# 1      1             1  cloudy       0            0  afternoon  winter

# %% [markdown]
# # 贝叶斯网络构建

# %%
from pgmpy.models import BayesianNetwork
model = BayesianNetwork([('time of week', 'temperature'),('time of week','volume'),
                         ('daytime','temperature'),('daytime','volume'),
                         ('season','temperature'),('season','volume'),('season','weather'),
                         ('weather','temperature'),('weather','volume'),('weather','crash'),
                         ('temperature','crash'),
                         ('volume','crash')])

# %% [markdown]
# # 模型评估

# %%
from pgmpy.metrics import structure_score
k2 = structure_score(model, data, scoring_method="k2") 
bdeu = structure_score(model, data, scoring_method="bdeu") 
bds  = structure_score(model, data, scoring_method="bds") 
bic = structure_score(model, data, scoring_method="bic")
print("K2:", k2)
print("BDeu:", bdeu)
print("BDs", bds)
print("BIC:", bic)
# Out:
# K2: -238913.00812345115
# BDeu: -239081.36505176625
# BDs -240110.7529786899
# BIC: -243757.27993152925

# %%
model1 = BayesianNetwork([('time of week','volume'),
                          ('volume','crash')])
data = data[['time of week','volume','crash']]
k2 = structure_score(model1, data, scoring_method="k2") 
bdeu = structure_score(model1, data, scoring_method="bdeu") 
bds  = structure_score(model1, data, scoring_method="bds") 
bic = structure_score(model1, data, scoring_method="bic")
print("K2:", k2)
print("BDeu:", bdeu)
print("BDs", bds)
print("BIC:", bic)
# Out:
# K2: -66567.44279271574
# BDeu: -66572.1302607096
# BDs -66575.5959966124
# BIC: -66572.84078519492

# %% [markdown]
# # 网络参数估计

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
estimator = MaximumLikelihoodEstimator(model, data)

# %%
cpd = estimator.estimate_cpd('crash')
print(cpd.variables)
print(cpd.cardinality)
pd.DataFrame(cpd.get_values())
# Out:
# ['crash', 'temperature', 'volume', 'weather']
# [2 3 3 5]
#          0         1         2         3         4         5         6   \
# 0  0.975464  0.983778  0.969646  0.925134  0.980999  0.941794  0.972851
# 1  0.024536  0.016222  0.030354  0.074866  0.019001  0.058206  0.027149
#
#         7         8         9   ...        35        36        37   38  \
# 0  0.93662  0.813665  0.951542  ...  0.965665  0.965714  0.966862  0.5
# 1  0.06338  0.186335  0.048458  ...  0.034335  0.034286  0.033138  0.5
#
#          39       40       41        42   43        44
# 0  0.922807  0.96308  0.97561  0.970588  0.5  0.982609
# 1  0.077193  0.03692  0.02439  0.029412  0.5  0.017391
#
# [2 rows x 45 columns]

# %%
cpd_matric = pd.DataFrame(cpd.get_values())
column_num = cpd_matric.shape[1]

# %% [markdown]
# # 事故的CPD

# %%
CPD = pd.DataFrame()

# %%
#crash:1 tem
list0 = np.array([])
list1 = np.array([])
list2 = np.array([])
large_unit = 0
unit = int(column_num/cpd.cardinality[1])
list0 = np.append(list0,np.linspace(int(large_unit),int(large_unit + unit)-1,int(unit))).astype(int)
list1 = np.append(list1,np.linspace(int(large_unit + unit),int(large_unit + 2*unit)-1,int(unit))).astype(int)
list2 = np.append(list2,np.linspace(int(large_unit + 2*unit),int(large_unit + 3*unit)-1,int(unit))).astype(int)

t0 = np.array([])
for i in list0:
    t0 = np.append(t0,cpd_matric[i][1])

t1 = np.array([])
for i in list1:
    t1 = np.append(t1,cpd_matric[i][1])

t2 = np.array([])
for i in list2:
    t2 = np.append(t2,cpd_matric[i][1])

CPD['crash_1_temperature_0'] = pd.DataFrame(t0)
CPD['crash_1_temperature_1'] = pd.DataFrame(t1)
CPD['crash_1_temperature_2'] = pd.DataFrame(t2)

# %%
#crash:1 low_tem
list0 = np.array([])
list1 = np.array([])
list2 = np.array([])
large_unit = int(column_num/(cpd.cardinality[1]))
unit = int(column_num/(cpd.cardinality[1]*cpd.cardinality[2]))
for i in range(cpd.cardinality[1]):
    list0 = np.append(list0,np.linspace(int(i*large_unit),int(i*large_unit+ unit)-1,int(unit))).astype(int)
    list1 = np.append(list1,np.linspace(int(i*large_unit + unit),int(i*large_unit+ 2*unit)-1,int(unit))).astype(int)
    list2 = np.append(list2,np.linspace(int(i*large_unit + 2*unit),int(i*large_unit+ 3*unit)-1,int(unit))).astype(int)

t0 = np.array([])
for i in list0:
    t0 = np.append(t0,cpd_matric[i][1])

t1 = np.array([])
for i in list1:
    t1 = np.append(t1,cpd_matric[i][1])

t2 = np.array([])
for i in list2:
    t2 = np.append(t2,cpd_matric[i][1])

CPD['crash_1_volume_0'] = pd.DataFrame(t0)
CPD['crash_1_volume_1'] = pd.DataFrame(t1)
CPD['crash_1_volume_2'] = pd.DataFrame(t2)

# %%
#crash:1 month
list0 = np.array([])
list1 = np.array([])
list2 = np.array([])
list3 = np.array([])
list4 = np.array([])
t0 = np.array([])
t1 = np.array([])
t2 = np.array([])
t3 = np.array([])
t4 = np.array([])

large_unit = int(column_num/(cpd.cardinality[1]*cpd.cardinality[2]))
unit = int(column_num/(cpd.cardinality[1]*cpd.cardinality[2]*cpd.cardinality[3]))
for i in range(cpd.cardinality[1]*cpd.cardinality[2]):
    list0 = np.append(list0,np.linspace(int(i*large_unit + 0*unit),int(i*large_unit+ 1*unit)-1,int(unit))).astype(int)
    list1 = np.append(list1,np.linspace(int(i*large_unit + 1*unit),int(i*large_unit+ 2*unit)-1,int(unit))).astype(int)
    list2 = np.append(list2,np.linspace(int(i*large_unit + 2*unit),int(i*large_unit+ 3*unit)-1,int(unit))).astype(int)
    list3 = np.append(list3,np.linspace(int(i*large_unit + 3*unit),int(i*large_unit+ 4*unit)-1,int(unit))).astype(int)
    list4 = np.append(list4,np.linspace(int(i*large_unit + 4*unit),int(i*large_unit+ 5*unit)-1,int(unit))).astype(int)

for i in list0:
    t0 = np.append(t0,cpd_matric[i][1])

for i in list1:
    t1 = np.append(t1,cpd_matric[i][1])

for i in list2:
    t2 = np.append(t2,cpd_matric[i][1])

for i in list3:
    t3 = np.append(t3,cpd_matric[i][1])

for i in list4:
    t4 = np.append(t4,cpd_matric[i][1])


CPD['crash_1_weather_0'] = pd.DataFrame(t0)
CPD['crash_1_weather_1'] = pd.DataFrame(t1)
CPD['crash_1_weather_2'] = pd.DataFrame(t2)
CPD['crash_1_weather_3'] = pd.DataFrame(t3)
CPD['crash_1_weather_4'] = pd.DataFrame(t4)

# %%
print(CPD.shape)
CPD.head(2)
# Out:
# (15, 11)
#    crash_1_temperature_0  crash_1_temperature_1  crash_1_temperature_2  \
# 0               0.024536               0.012014               0.016139
# 1               0.016222               0.024659               0.029685
#
#    crash_1_volume_0  crash_1_volume_1  crash_1_volume_2  crash_1_weather_0  \
# 0          0.024536          0.058206          0.020367           0.024536
# 1          0.016222          0.027149          0.010870           0.058206
#
#    crash_1_weather_1  crash_1_weather_2  crash_1_weather_3  crash_1_weather_4
# 0           0.016222           0.030354           0.074866           0.019001
# 1           0.027149           0.063380           0.186335           0.048458

# %%
CPD.to_excel('CPD_crash_1.xlsx',index=None)

# %% [markdown]
# # 贝叶斯网络推断

# %%
model.fit(data)

# %%
from pgmpy.inference import VariableElimination
inference = VariableElimination(model)

# %%
inference = inference.query(['time of week','daytime','weather','season','temperature','volume','crash'],joint=True)

# %%
print(inference)
# Out:
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week    | daytime            | weather         | season         | temperature    | volume    | crash    |   phi(time of week,daytime,weather,season,temperature,volume,crash) |
# +=================+====================+=================+================+================+===========+==========+=====================================================================+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(0) | volume(0) | crash(0) |                                                              0.0004 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(0) | volume(1) | crash(0) |                                                              0.0002 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(0) | volume(2) | crash(0) |                                                              0.0002 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(1) | volume(0) | crash(0) |                                                              0.0045 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(1) | volume(0) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(1) | volume(1) | crash(0) |                                                              0.0026 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(1) | volume(1) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(1) | volume(2) | crash(0) |                                                              0.0022 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(1) | volume(2) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(2) | volume(0) | crash(0) |                                                              0.0016 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(2) | volume(1) | crash(0) |                                                              0.0009 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(2) | volume(2) | crash(0) |                                                              0.0007 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(autumn) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(0) | volume(0) | crash(0) |                                                              0.0014 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(0) | volume(1) | crash(0) |                                                              0.0003 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(0) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(1) | volume(0) | crash(0) |                                                              0.0094 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(1) | volume(0) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(1) | volume(1) | crash(0) |                                                              0.0019 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(1) | volume(1) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(1) | volume(2) | crash(0) |                                                              0.0002 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(2) | volume(0) | crash(0) |                                                              0.0033 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(2) | volume(0) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(2) | volume(1) | crash(0) |                                                              0.0007 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(2) | volume(2) | crash(0) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(spring) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(0) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(0) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(0) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(1) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(1) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(1) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(1) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(2) | volume(0) | crash(0) |                                                              0.0045 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(2) | volume(0) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(2) | volume(1) | crash(0) |                                                              0.0093 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(2) | volume(1) | crash(1) |                                                              0.0003 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(2) | volume(2) | crash(0) |                                                              0.0037 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(summer) | temperature(2) | volume(2) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(0) | volume(0) | crash(0) |                                                              0.0091 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(0) | volume(0) | crash(1) |                                                              0.0002 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(0) | volume(1) | crash(0) |                                                              0.0066 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(0) | volume(1) | crash(1) |                                                              0.0004 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(0) | volume(2) | crash(0) |                                                              0.0047 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(0) | volume(2) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(1) | volume(0) | crash(0) |                                                              0.0005 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(1) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(1) | volume(1) | crash(0) |                                                              0.0004 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(1) | volume(2) | crash(0) |                                                              0.0003 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(2) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(2) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(2) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(cloudy) | season(winter) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(0) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(0) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(0) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(1) | volume(0) | crash(0) |                                                              0.0036 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(1) | volume(0) | crash(1) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(1) | volume(1) | crash(0) |                                                              0.0020 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(1) | volume(2) | crash(0) |                                                              0.0013 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(2) | volume(0) | crash(0) |                                                              0.0010 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(2) | volume(1) | crash(0) |                                                              0.0005 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(2) | volume(2) | crash(0) |                                                              0.0004 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(autumn) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(0) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(0) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(0) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(1) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(1) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(1) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(1) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(2) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(2) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(2) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(spring) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(0) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(0) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(0) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(1) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(1) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(1) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(1) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(2) | volume(0) | crash(0) |                                                              0.0002 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(2) | volume(1) | crash(0) |                                                              0.0003 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(2) | volume(2) | crash(0) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(summer) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(winter) | temperature(0) | volume(0) | crash(0) |                                                              0.0025 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(0) | daytime(afternoon) | weather(foggy)  | season(winter) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# ...
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(2) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(2) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(2) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(spring) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(0) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(0) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(0) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(1) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(1) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(1) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(1) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(2) | volume(0) | crash(0) |                                                              0.0002 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(2) | volume(1) | crash(0) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(2) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(summer) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(0) | volume(0) | crash(0) |                                                              0.0003 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(0) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(0) | volume(1) | crash(0) |                                                              0.0003 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(0) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(0) | volume(2) | crash(0) |                                                              0.0001 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(0) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(1) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(1) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(1) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(1) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(1) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(1) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(2) | volume(0) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(2) | volume(0) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(2) | volume(1) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(2) | volume(1) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(2) | volume(2) | crash(0) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+
# | time of week(2) | daytime(noon)      | weather(sunny)  | season(winter) | temperature(2) | volume(2) | crash(1) |                                                              0.0000 |
# +-----------------+--------------------+-----------------+----------------+----------------+-----------+----------+---------------------------------------------------------------------+

# %%
inference.variables
# Out:
# ['time of week',
#  'daytime',
#  'weather',
#  'season',
#  'temperature',
#  'volume',
#  'crash']

# %%
inference.cardinality
# Out:
# array([3, 6, 5, 4, 3, 3, 2])

# %%
infer_values = inference.values
print(type(infer_values))
print(infer_values.shape)
infer_values = infer_values.reshape(3*6*5*4*3*3*2,1)
#pd.DataFrame(infer_values).to_excel('inference_data.xlsx',index=None)
# Out:
# <class 'numpy.ndarray'>
# (3, 6, 5, 4, 3, 3, 2)

# %%
infer_values = pd.DataFrame(infer_values)
infer_values.columns = ['p']

# %%
crash = [int(np.floor(i%2)) for i in range(len(infer_values))]
infer_values = pd.concat([infer_values,pd.DataFrame(crash,columns=['crash'])],axis=1)

# %%
volume = [int(np.floor(i%(2*3))) for i in range(len(infer_values))]
volume = [int(np.floor(i/2)) for i in volume]
infer_values = pd.concat([infer_values,pd.DataFrame(volume,columns=['volume'])],axis=1)

# %%
temperature = [int(np.floor(i%(2*3*3))) for i in range(len(infer_values))]
temperature = [int(np.floor(i/(2*3))) for i in temperature]
infer_values = pd.concat([infer_values,pd.DataFrame(temperature,columns=['temperature'])],axis=1)

# %%
season = [int(np.floor(i%(2*3*3*4))) for i in range(len(infer_values))]
season = [int(np.floor(i/(2*3*3))) for i in season]
infer_values = pd.concat([infer_values,pd.DataFrame(season,columns=['season'])],axis=1)

# %%
weather = [int(np.floor(i%(2*3*3*4*5))) for i in range(len(infer_values))]
weather = [int(np.floor(i/(2*3*3*4))) for i in weather]
infer_values = pd.concat([infer_values,pd.DataFrame(weather,columns=['weather'])],axis=1)

# %%
daytime = [int(np.floor(i%(2*3*3*4*5*6))) for i in range(len(infer_values))]
daytime = [int(np.floor(i/(2*3*3*4*5))) for i in daytime]
infer_values = pd.concat([infer_values,pd.DataFrame(daytime,columns=['daytime'])],axis=1)

# %%
time_of_week = [int(np.floor(i%(2*3*3*4*5*6*3))) for i in range(len(infer_values))]
time_of_week = [int(np.floor(i/(2*3*3*4*5*6))) for i in time_of_week]
infer_values = pd.concat([infer_values,pd.DataFrame(time_of_week,columns=['time of week'])],axis=1)

# %%
infer_values
# Out:
#              p  crash  volume  temperature  season  weather  daytime  \
# 0     0.000403      0       0            0       0        0        0
# 1     0.000010      1       0            0       0        0        0
# 2     0.000222      0       1            0       0        0        0
# 3     0.000014      1       1            0       0        0        0
# 4     0.000197      0       2            0       0        0        0
# ...        ...    ...     ...          ...     ...      ...      ...
# 6475  0.000000      1       0            2       3        4        5
# 6476  0.000000      0       1            2       3        4        5
# 6477  0.000000      1       1            2       3        4        5
# 6478  0.000000      0       2            2       3        4        5
# 6479  0.000000      1       2            2       3        4        5
#
#       time of week
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 6475             2
# 6476             2
# 6477             2
# 6478             2
# 6479             2
#
# [6480 rows x 8 columns]

# %%
def cseason(x):
    t = 0
    if (x-0)<0.1:
        t = 'autumn'
    elif (x-1)<0.1:
        t = 'spring'
    elif (x-2)<0.1:
        t = 'summer'
    elif (x-3)<0.1:
        t = 'winter'
    return t
infer_values['season'] = infer_values.apply(lambda infer_values:cseason(infer_values['season']),axis=1)

# %%
def cweather(x):
    t = 0
    if (x-0)<0.1:
        t = 'cloudy'
    elif (x-1)<0.1:
        t = 'foggy'
    elif (x-2)<0.1:
        t = 'rainy'
    elif (x-3)<0.1:
        t = 'snowy'
    elif (x-4)<0.1:
        t = 'sunny'
    return t
infer_values['weather'] = infer_values.apply(lambda infer_values:cweather(infer_values['weather']),axis=1)

# %%
def cdaytime(x):
    t = 0
    if (x-0)<0.1:
        t = 'afternoon'
    elif (x-1)<0.1:
        t = 'dawn'
    elif (x-2)<0.1:
        t = 'evening'
    elif (x-3)<0.1:
        t = 'morning'
    elif (x-4)<0.1:
        t = 'night'
    elif (x-5)<0.1:
        t = 'noon'
    return t
infer_values['daytime'] = infer_values.apply(lambda infer_values:cdaytime(infer_values['daytime']),axis=1)

# %%
infer_values
# Out:
#              p  crash  volume  temperature  season weather    daytime  \
# 0     0.000403      0       0            0  autumn  cloudy  afternoon
# 1     0.000010      1       0            0  autumn  cloudy  afternoon
# 2     0.000222      0       1            0  autumn  cloudy  afternoon
# 3     0.000014      1       1            0  autumn  cloudy  afternoon
# 4     0.000197      0       2            0  autumn  cloudy  afternoon
# ...        ...    ...     ...          ...     ...     ...        ...
# 6475  0.000000      1       0            2  winter   sunny       noon
# 6476  0.000000      0       1            2  winter   sunny       noon
# 6477  0.000000      1       1            2  winter   sunny       noon
# 6478  0.000000      0       2            2  winter   sunny       noon
# 6479  0.000000      1       2            2  winter   sunny       noon
#
#       time of week
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 6475             2
# 6476             2
# 6477             2
# 6478             2
# 6479             2
#
# [6480 rows x 8 columns]

# %%
infer_values.to_excel('推断数据.xlsx',index=None)
